# %% [markdown]
# # Fine-Tune a Generative AI Model for Dialogue Summarization

# %% [markdown]
# In this notebook, you will fine-tune an existing LLM from Hugging Face for enhanced dialogue summarization. You will use the [FLAN-T5](https://huggingface.co/docs/transformers/model_doc/flan-t5) model, which provides a high quality instruction tuned model and can summarize text out of the box. To improve the inferences, you will explore a full fine-tuning approach and evaluate the results with ROUGE metrics. Then you will perform Parameter Efficient Fine-Tuning (PEFT), evaluate the resulting model and see that the benefits of PEFT outweigh the slightly-lower performance metrics.

# %% [markdown]
# # Table of Contents

# %% [markdown]
# - [ 1 - Set up Kernel, Load Required Dependencies, Dataset and LLM](#1)
#   - [ 1.1 - Set up Kernel and Required Dependencies](#1.1)
#   - [ 1.2 - Load Dataset and LLM](#1.2)
#   - [ 1.3 - Test the Model with Zero Shot Inferencing](#1.3)
# - [ 2 - Perform Full Fine-Tuning](#2)
#   - [ 2.1 - Preprocess the Dialog-Summary Dataset](#2.1)
#   - [ 2.2 - Fine-Tune the Model with the Preprocessed Dataset](#2.2)
#   - [ 2.3 - Evaluate the Model Qualitatively (Human Evaluation)](#2.3)
#   - [ 2.4 - Evaluate the Model Quantitatively (with ROUGE Metric)](#2.4)
# - [ 3 - Perform Parameter Efficient Fine-Tuning (PEFT)](#3)
#   - [ 3.1 - Setup the PEFT/LoRA model for Fine-Tuning](#3.1)
#   - [ 3.2 - Train PEFT Adapter](#3.2)
#   - [ 3.3 - Evaluate the Model Qualitatively (Human Evaluation)](#3.3)
#   - [ 3.4 - Evaluate the Model Quantitatively (with ROUGE Metric)](#3.4)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Set up Kernel, Load Required Dependencies, Dataset and LLM

# %% [markdown]
# <a name='1.1'></a>
# ### 1.1 - Set up Kernel and Required Dependencies

# %% [markdown]
# To begin with, check that the kernel is selected correctly.
#
# <img src="images/kernel_set_up.png" width="300"/>
#
# If you click on that (top right of the screen), you'll be able to see and check the details of the image, kernel, and instance type.
#
# <img src="images/w2_kernel_and_instance_type.png" width="600"/>
#
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %%
import os

instance_type_expected = 'ml-m5-2xlarge'
instance_type_current = os.environ.get('HOSTNAME')

print(f'Expected instance type: instance-datascience-{instance_type_expected}')
print(f'Currently chosen instance type: {instance_type_current}')

assert instance_type_expected in instance_type_current, f'ERROR. You selected the {instance_type_current} instance type. Please select {instance_type_expected} instead as shown on the screenshot above'
print("Instance type has been chosen correctly.")

# %% [markdown]
# Now install the required packages for the LLM and datasets.
#
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
# %pip install -U datasets==2.17.0

# %pip install --upgrade pip
# %pip install --disable-pip-version-check \
    torch==1.13.1 \
    torchdata==0.5.1 --quiet

# %pip install \
    transformers==4.27.2 \
    evaluate==0.4.0 \
    rouge_score==0.1.2 \
    loralib==0.1.1 \
    peft==0.3.0 --quiet
# Out:
# Requirement already satisfied: datasets==2.17.0 in c:\users\paish\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: filelock in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (1.26.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (0.3.6)
# Requirement already satisfied: pandas in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (0.70.14)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in c:\users\paish\anaconda3\lib\site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.17.0) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (3.9.0)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (0.21.4)
# Requirement already satisfied: packaging in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\paish\anaconda3\lib\site-packages (from datasets==2.17.0) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\paish\anaconda3\lib\site-packages (from aiohttp->datasets==2.17.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\paish\anaconda3\lib\site-packages (from aiohttp->datasets==2.17.0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\paish\anaconda3\lib\site-packages (from aiohttp->datasets==2.17.0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\paish\anaconda3\lib\site-packages (from aiohttp->datasets==2.17.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\paish\anaconda3\lib\site-packages (from aiohttp->datasets==2.17.0) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\paish\anaconda3\lib\site-packages (from huggingface-hub>=0.19.4->datasets==2.17.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paish\anaconda3\lib\site-packages (from requests>=2.19.0->datasets==2.17.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paish\anaconda3\lib\site-packages (from requests>=2.19.0->datasets==2.17.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paish\anaconda3\lib\site-packages (from requests>=2.19.0->datasets==2.17.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paish\anaconda3\lib\site-packages (from requests>=2.19.0->datasets==2.17.0) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\paish\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets==2.17.0) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\paish\anaconda3\lib\site-packages (from pandas->datasets==2.17.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paish\anaconda3\lib\site-packages (from pandas->datasets==2.17.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\paish\anaconda3\lib\site-packages (from pandas->datasets==2.17.0) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\paish\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets==2.17.0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in c:\users\paish\anaconda3\lib\site-packages (24.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement torch==1.13.1 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1)
# ERROR: No matching distribution found for torch==1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# Import the necessary components. Some of them are new for this week, they will be discussed later in the notebook.

# %%
from datasets import load_dataset
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GenerationConfig, TrainingArguments, Trainer
import torch
import time
import evaluate
import pandas as pd
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\paish\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <a name='1.2'></a>
# ### 1.2 - Load Dataset and LLM
#
# You are going to continue experimenting with the [DialogSum](https://huggingface.co/datasets/knkarthick/dialogsum) Hugging Face dataset. It contains 10,000+ dialogues with the corresponding manually labeled summaries and topics.

# %%
huggingface_dataset_name = "knkarthick/dialogsum"

dataset = load_dataset(huggingface_dataset_name)

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 12460
#     })
#     validation: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 500
#     })
#     test: Dataset({
#         features: ['id', 'dialogue', 'summary', 'topic'],
#         num_rows: 1500
#     })
# })

# %% [markdown]
# Load the pre-trained [FLAN-T5 model](https://huggingface.co/docs/transformers/model_doc/flan-t5) and its tokenizer directly from HuggingFace. Notice that you will be using the [small version](https://huggingface.co/google/flan-t5-base) of FLAN-T5. Setting `torch_dtype=torch.bfloat16` specifies the memory type to be used by this model.

# %%
model_name='google/flan-t5-base'

original_model = AutoModelForSeq2SeqLM.from_pretrained(model_name, torch_dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
list(original_model.named_parameters())
# Out:
# [('shared.weight',
#   Parameter containing:
#   tensor([[-4.0820e-01,  1.2734e+00, -1.3379e-01,  ..., -8.0078e-01,
#             3.9219e+00,  9.7046e-03],
#           [ 1.5812e+01,  7.1875e+00,  1.5125e+01,  ...,  5.4375e+00,
#            -2.5875e+01,  1.1500e+01],
#           [-1.8438e+00, -8.9062e-01, -1.2938e+01,  ...,  4.0938e+00,
#             5.0625e+00, -3.7656e+00],
#           ...,
#           [ 5.6641e-01, -1.3594e+00, -1.1953e+00,  ...,  1.4648e-01,
#            -5.0781e-01, -1.2109e+00],
#           [-8.9062e-01,  8.1641e-01,  6.3672e-01,  ..., -1.2012e-01,
#             9.4922e-01, -1.5938e+00],
#           [-8.3203e-01,  1.8281e+00,  1.3770e-01,  ..., -2.1094e-01,
#            -1.1875e+00, -5.1172e-01]], dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.0.layer.0.SelfAttention.q.weight',
#   Parameter containing:
#   tensor([[-0.0145,  0.1377,  0.0090,  ..., -0.0583, -0.0356, -0.0124],
#           [ 0.0618,  0.0142, -0.0118,  ..., -0.0603, -0.0537, -0.0179],
#           [ 0.0052, -0.0435, -0.0508,  ...,  0.0757, -0.0420,  0.0903],
#           ...,
#           [-0.0038,  0.0090,  0.0383,  ...,  0.0461,  0.0077, -0.0044],
#           [-0.0253, -0.0388,  0.0070,  ...,  0.0481,  0.0232, -0.0383],
#           [ 0.0055, -0.0033, -0.0223,  ...,  0.0291, -0.0317, -0.0106]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.0.layer.0.SelfAttention.k.weight',
#   Parameter containing:
#   tensor([[ 7.3547e-03,  6.6016e-01,  2.2559e-01,  ..., -6.0547e-01,
#            -2.2949e-01, -2.2339e-02],
#           [ 3.0469e-01, -2.4219e-01,  2.3438e-02,  ..., -5.2734e-01,
#             3.7384e-03, -5.7422e-01],
#           [ 5.1172e-01, -3.5547e-01, -6.6406e-01,  ...,  1.6602e-01,
#            -9.1406e-01,  9.2578e-01],
#           ...,
#           [ 3.8086e-01,  2.7930e-01,  1.0071e-02,  ...,  1.1572e-01,
#             1.2158e-01, -2.9492e-01],
#           [ 7.4387e-04, -4.9805e-01,  4.3750e-01,  ...,  2.3804e-02,
#            -4.1602e-01, -7.3242e-03],
#           [ 1.5820e-01, -8.9844e-02, -4.2188e-01,  ..., -6.1768e-02,
#             2.2949e-01,  1.5137e-01]], dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.0.layer.0.SelfAttention.v.weight',
#   Parameter containing:
#   tensor([[ 0.4219,  0.0588, -0.4316,  ..., -0.0981,  0.2969, -0.1416],
#           [-0.6484, -0.0165,  0.1641,  ...,  0.0089,  0.1973,  0.0221],
#           [-0.2656,  0.0011,  0.1699,  ..., -0.2305, -0.3223,  0.0214],
#           ...,
#           [ 0.1260, -0.0131, -0.2695,  ...,  0.2275, -0.0129, -0.0083],
#           [ 0.0532, -0.0232, -0.0566,  ...,  0.1030,  0.1885,  0.1504],
#           [ 0.0018,  0.0244, -0.1611,  ..., -0.0747, -0.0171,  0.1963]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.0.layer.0.SelfAttention.o.weight',
#   Parameter containing:
#   tensor([[-0.1836,  0.4434,  0.1094,  ..., -0.0130, -0.1445, -0.0532],
#           [-0.1367, -0.0021,  0.2559,  ...,  0.0018, -0.1099, -0.0466],
#           [ 0.0669, -0.1191, -0.0574,  ..., -0.2539, -0.2178, -0.0515],
#           ...,
#           [-0.0481, -0.2539,  0.0669,  ..., -0.3340, -0.0184,  0.4551],
#           [-0.1367, -0.1953,  0.1167,  ..., -0.1582,  0.3379,  0.2109],
#           [-0.0630, -0.0457, -0.3086,  ...,  0.3398,  0.1826,  0.4277]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.0.layer.0.SelfAttention.relative_attention_bias.weight',
#   Parameter containing:
#   tensor([[ 3.3125e+00, -1.4125e+01,  2.2344e+00, -7.5625e+00,  8.3750e+00,
#             5.4062e+00,  4.9023e-01,  2.5195e-01,  4.3438e+00,  6.5938e+00,
#            -8.6875e+00, -2.5500e+01],
#           [-2.5750e+01,  1.0500e+01,  8.5000e+00,  3.9531e+00,  9.8750e+00,
#             1.7500e+00,  9.1875e+00,  6.1250e+00,  7.9375e+00, -4.2188e+00,
#             2.8125e+00,  7.6875e+00],
#           [-1.5938e+01,  8.7500e+00,  5.2812e+00,  4.5625e+00,  7.7812e+00,
#             9.4922e-01,  8.6250e+00,  6.6250e+00,  7.5312e+00, -1.7500e+01,
type=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.0.SelfAttention.q.weight',
#   Parameter containing:
#   tensor([[ 0.0708, -0.0065, -0.0148,  ..., -0.0074, -0.0515, -0.0208],
#           [ 0.0243,  0.0327,  0.0415,  ..., -0.0127, -0.0527,  0.0332],
#           [ 0.0493,  0.0064, -0.0483,  ..., -0.0053, -0.0664, -0.0386],
#           ...,
#           [ 0.0146, -0.0437, -0.0796,  ..., -0.0183, -0.1147, -0.0160],
#           [-0.0036,  0.0713, -0.0098,  ..., -0.0474, -0.0253,  0.0991],
#           [ 0.0320, -0.0723, -0.0408,  ...,  0.0640, -0.0581,  0.0112]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.0.SelfAttention.k.weight',
#   Parameter containing:
#   tensor([[ 0.4121, -0.3613, -0.3262,  ...,  0.3770, -0.0684,  0.2344],
#           [ 0.3535, -0.1328, -0.0008,  ...,  0.2021, -0.1172,  0.0457],
#           [ 0.0991,  0.1855,  0.6484,  ..., -0.1904, -0.0718,  0.7852],
#           ...,
#           [ 0.6445,  0.2520,  0.3496,  ..., -0.2393, -0.2598,  0.4746],
#           [-0.3398,  0.0537,  0.3066,  ...,  0.1069,  0.3223,  0.5273],
#           [-0.3105, -0.1387, -0.0058,  ...,  0.1309, -0.0625, -0.0317]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.0.SelfAttention.v.weight',
#   Parameter containing:
#   tensor([[-0.5430, -0.2217,  0.2656,  ...,  0.0762,  0.1001,  0.1040],
#           [-0.7812, -0.0669,  0.1152,  ...,  0.4902,  0.2168, -0.2148],
#           [ 0.1387, -0.4316,  0.3438,  ..., -0.1279, -0.2656, -0.2852],
#           ...,
#           [-0.0032,  0.3555,  0.0508,  ..., -0.0603,  0.0879,  0.5117],
#           [ 0.4629, -0.0342, -0.3984,  ..., -0.0654, -0.2773, -0.0664],
#           [ 0.1387,  0.1768, -0.0718,  ..., -0.1465,  0.4922,  0.0242]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.0.SelfAttention.o.weight',
#   Parameter containing:
#   tensor([[-0.1846, -0.3691, -0.0830,  ...,  0.2949,  0.1680,  0.0571],
#           [ 0.0159,  0.5781,  0.8164,  ...,  0.1387,  0.0898, -0.3418],
#           [ 0.5234, -0.3086,  0.2373,  ...,  0.3203, -0.4004, -0.2695],
#           ...,
#           [-0.1099, -0.3926, -0.4805,  ..., -0.2949, -0.1729,  0.0535],
#           [ 0.0255,  0.3223,  0.5117,  ..., -0.6523,  0.1904,  0.4512],
#           [-0.0869,  0.5273, -0.0942,  ...,  0.0625, -0.2969,  0.1040]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer

#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.1.DenseReluDense.wi_0.weight',
#   Parameter containing:
#   tensor([[ 0.2871,  0.0874,  0.6328,  ...,  0.8203, -0.2852, -0.8945],
#           [-0.0593,  0.3770, -0.2695,  ...,  0.5703,  0.2266,  0.3574],
#           [-0.3359, -0.6953,  0.1416,  ..., -0.2188, -0.3223, -0.4102],
#           ...,
#           [ 0.4492, -0.0889,  0.3809,  ..., -0.5742,  0.0422, -0.3418],
#           [ 0.3730, -0.1514,  0.2500,  ..., -0.2305, -0.3145, -0.3105],
#           [ 0.2256,  0.0708,  0.1064,  ..., -0.1436, -0.2559,  0.2363]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.1.DenseReluDense.wi_1.weight',
#   Parameter containing:
#   tensor([[ 0.1387,  0.0544,  0.2793,  ..., -0.6367,  0.5859, -1.0000],
#           [-0.2852, -0.2412,  0.0679,  ...,  0.3086, -0.1011, -0.0962],
#           [ 0.1631, -0.0942,  0.0894,  ..., -0.3555, -0.0815, -0.0894],
#           ...,
#           [ 0.7383,  0.2793, -0.1191,  ...,  0.5469,  0.0767, -0.4121],
#           [-0.5547,  0.0219, -0.4160,  ...,  0.3574, -0.0100,  0.1807],
#           [ 0.1768,  0.1543, -0.0129,  ...,  0.0693, -0.7500, -0.0093]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.1.DenseReluDense.wo.weight',
#   Parameter containing:
#   tensor([[-0.0752,  0.2715,  0.0957,  ..., -0.3672,  0.2090,  0.2500],
#           [ 0.0659,  0.3027, -0.1211,  ..., -0.0508,  0.0825, -0.1309],
#           [ 0.4785,  0.0229,  0.2275,  ..., -0.0229,  0.1426,  0.0098],
#           ...,
#           [ 0.2451, -0.0537,  0.1709,  ..., -0.1074, -0.1631, -0.0464],
#           [ 0.2051,  0.1768,  0.0708,  ...,  0.0562,  0.3027,  0.2500],
#           [-0.2715, -0.2354, -0.1299,  ..., -0.3906,  0.0334, -0.6992]],
#          dtype=torch.bfloat16, requires_grad=True)),
#  ('encoder.block.1.layer.1.layer_norm.weight',
#   Parameter containing:
#   tensor([ 1.1768e-01,  9.7168e-02,  9.1797e-02,  1.2878e-02,  9.1309e-02,
#            7.8125e-02,  9.0820e-02,  7.9102e-02,  1.0840e-01,  8.7891e-02,
#            7.1777e-02,  8.6426e-02,  9.6191e-02,  9.4238e-02,  9.1797e-02,
#            8.1055e-02,  4.1992e-01,  6.5430e-02,  7.1289e-02,  9.4238e-02,
#            7.5195e-02,  8.1543e-02,  9.7168e-02,  1.1230e-01,  7.2266e-02,
#            1.3379e-01,  1.0449e-01,  1.0693e-01,  9.1309e-02,  1.0010e-01,
#            1.1377e-01,  1.5332e-01,  9.0332e-02,  8.8867e-02,  7.3730e-02,
#            8.8379e-02,  8.7891e-02,  8.1543e-02,  8.8379e-02,  8.3984e-02,
#            1.0986e-01,  1.1279e-01,  9.6191e-02,  8.1543e-02,  8.3008e-02,
#            8.9844e-02,  1.0645e-01,  8.4961e-02,  1.2695e-01,  9.9121e-02,
#            1.1035e-01,  1.3379e-01,  4.8340e-02,  1.1865e-01,  1.2451e-01,
#           0.4629, 0.3672, 0.7461, 0.3730, 0.3652, 0.4023, 0.3965, 0.5117, 0.5820,
#           0.6211, 0.3320, 0.3730, 0.5938, 0.4746, 0.4551, 0.5391, 0.4336, 0.3340,
#           0.4258, 0.5938, 0.4453, 0.6211, 0.4902, 0.3965, 0.4258, 0.5273, 0.4453,
#           0.4688, 0.3652, 0.4297, 0.3477, 0.3789, 0.5039, 0.4277, 0.3496, 0.4629,
#           0.3926, 0.4512, 0.6875, 0.3594, 0.3633, 0.3184, 0.4395, 0.4531, 0.3867,
#           0.6562, 0.3867, 0.5312, 0.5078, 0.3672, 0.6289, 0.3809, 5.9375, 0.4375,
#           0.3691, 0.4062, 0.3750, 0.4609, 0.4473, 0.4941, 0.5195, 0.3770, 0.4707,
#           0.3438, 0.3125, 0.3262, 0.4727, 0.4355, 0.6094, 0.4609, 0.4668, 0.4180,
#           0.5625, 0.3828, 0.4062], dtype=torch.bfloat16, requires_grad=True)),
#  ('lm_head.weight',
#   Parameter containing:
#   tensor([[-0.5938,  0.9023, -0.8398,  ..., -1.3516,  0.3340,  0.6328],
#           [ 0.4258, -0.1475, -0.0325,  ..., -0.1719, -0.4473, -0.2891],
#           [-0.3965,  1.9766,  0.5820,  ...,  0.1406, -0.9023, -0.2832],
#           ...,
#           [-0.6289,  0.9297, -0.8594,  ..., -1.3516,  0.3379,  0.6758],
#           [-0.6133,  0.9062, -0.8320,  ..., -1.3672,  0.3359,  0.6328],
#           [-0.6016,  0.9727, -0.8711,  ..., -1.3125,  0.3340,  0.6172]],
#          dtype=torch.bfloat16, requires_grad=True))]

# %% [markdown]
# requires_grad=True: The requires_grad attribute of the tensor is set to True, indicating that gradients will be computed for this tensor during backpropagation. This means that the tensor's values will be updated during the optimization process (e.g., gradient descent) to minimize the loss function and improve the model's performance on the training data.

# %% [markdown]
# It is possible to pull out the number of model parameters and find out how many of them are trainable. The following function can be used to do that, at this stage, you do not need to go into details of it.

# %%
def print_number_of_trainable_model_parameters(model):
    trainable_model_params = 0
    all_model_params = 0
    for _, param in model.named_parameters():
        all_model_params += param.numel()
        if param.requires_grad:
            trainable_model_params += param.numel()
    return f"trainable model parameters: {trainable_model_params}\nall model parameters: {all_model_params}\npercentage of trainable model parameters: {100 * trainable_model_params / all_model_params:.2f}%"

print(print_number_of_trainable_model_parameters(original_model))
# Out:
# trainable model parameters: 247577856
# all model parameters: 247577856
# percentage of trainable model parameters: 100.00%

# %% [markdown]
# In PyTorch, the .numel() method is used to compute the number of elements in a tensor. The name "numel" stands for "number of elements". It returns the total number of elements in the tensor, which is equal to the product of the sizes of all dimensions of the tensor.

# %% [markdown]
# <a name='1.3'></a>
# ### 1.3 - Test the Model with Zero Shot Inferencing
#
# Test the model with the zero shot inferencing. You can see that the model struggles to summarize the dialogue compared to the baseline summary, but it does pull out some important information from the text which indicates the model can be fine-tuned to the task at hand.

# %%
index = 200

dialogue = dataset['test'][index]['dialogue']
summary = dataset['test'][index]['summary']

prompt = f"""
Summarize the following conversation.

{dialogue}

Summary:
"""

inputs = tokenizer(prompt, return_tensors='pt')
output = tokenizer.decode(
    original_model.generate(
        inputs["input_ids"], 
        max_new_tokens=200,
    )[0], 
    skip_special_tokens=True
)

dash_line = '-'.join('' for x in range(100))
print(dash_line)
print(f'INPUT PROMPT:\n{prompt}')
print(dash_line)
print(f'BASELINE HUMAN SUMMARY:\n{summary}\n')
print(dash_line)
print(f'MODEL GENERATION - ZERO SHOT:\n{output}')
# Out:
# ---------------------------------------------------------------------------------------------------
# INPUT PROMPT:
#
# Summarize the following conversation.
#
# #Person1#: Have you considered upgrading your system?
# #Person2#: Yes, but I'm not sure what exactly I would need.
# #Person1#: You could consider adding a painting program to your software. It would allow you to make up your own flyers and banners for advertising.
# #Person2#: That would be a definite bonus.
# #Person1#: You might also want to upgrade your hardware because it is pretty outdated now.
# #Person2#: How can we do that?
# #Person1#: You'd probably need a faster processor, to begin with. And you also need a more powerful hard disc, more memory and a faster modem. Do you have a CD-ROM drive?
# #Person2#: No.
# #Person1#: Then you might want to add a CD-ROM drive too, because most new software programs are coming out on Cds.
# #Person2#: That sounds great. Thanks.
#
# Summary:
#
# ---------------------------------------------------------------------------------------------------
# BASELINE HUMAN SUMMARY:
# #Person1# teaches #Person2# how to upgrade software and hardware in #Person2#'s system.
#
# ---------------------------------------------------------------------------------------------------
# MODEL GENERATION - ZERO SHOT:
# #Person1#: I'm thinking of upgrading my computer.

# %% [markdown]
# <a name='2'></a>
# ## 2 - Perform Full Fine-Tuning

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Preprocess the Dialog-Summary Dataset
#
# You need to convert the dialog-summary (prompt-response) pairs into explicit instructions for the LLM. Prepend an instruction to the start of the dialog with `Summarize the following conversation` and to the start of the summary with `Summary` as follows:
#
# Training prompt (dialogue):
# ```
# Summarize the following conversation.
#
#     Chris: This is his part of the conversation.
#     Antje: This is her part of the conversation.
#
# Summary:
# ```
#
# Training response (summary):
# ```
# Both Chris and Antje participated in the conversation.
# ```
#
# Then preprocess the prompt-response dataset into tokens and pull out their `input_ids` (1 per token).

# %%
def tokenize_function(example):
    start_prompt = 'Summarize the following conversation.\n\n'
    end_prompt = '\n\nSummary: '
    prompt = [start_prompt + dialogue + end_prompt for dialogue in example["dialogue"]]
    example['input_ids'] = tokenizer(prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids
    example['labels'] = tokenizer(example["summary"], padding="max_length", truncation=True, return_tensors="pt").input_ids
    
    return example

# The dataset actually contains 3 diff splits: train, validation, test.
# The tokenize_function code is handling all data across all splits in batches.
tokenized_datasets = dataset.map(tokenize_function, batched=True)
tokenized_datasets = tokenized_datasets.remove_columns(['id', 'topic', 'dialogue', 'summary',])
# Out:
# Map:   0%|          | 0/12460 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %% [markdown]
# To save some time in the lab, you will subsample the dataset:

# %%
tokenized_datasets = tokenized_datasets.filter(lambda example, index: index % 100 == 0, with_indices=True)
# Out:
# Filter:   0%|          | 0/12460 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/500 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %% [markdown]
# Check the shapes of all three parts of the dataset:

# %%
print(f"Shapes of the datasets:")
print(f"Training: {tokenized_datasets['train'].shape}")
print(f"Validation: {tokenized_datasets['validation'].shape}")
print(f"Test: {tokenized_datasets['test'].shape}")

print(tokenized_datasets)
# Out:
# Shapes of the datasets:
# Training: (125, 2)
# Validation: (5, 2)
# Test: (15, 2)
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 125
#     })
#     validation: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 5
#     })
#     test: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 15
#     })
# })

# %% [markdown]
# The output dataset is ready for fine-tuning.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Fine-Tune the Model with the Preprocessed Dataset
#
# Now utilize the built-in Hugging Face `Trainer` class (see the documentation [here](https://huggingface.co/docs/transformers/main_classes/trainer)). Pass the preprocessed dataset with reference to the original model. Other training parameters are found experimentally and there is no need to go into details about those at the moment.

# %%
output_dir = f'./dialogue-summary-training-{str(int(time.time()))}'

training_args = TrainingArguments(
    output_dir=output_dir,
    learning_rate=1e-5,
    num_train_epochs=1,
    weight_decay=0.01,
    logging_steps=1,
    max_steps=1
)

trainer = Trainer(
    model=original_model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation']
)

# %% [markdown]
# Start training process...
#
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
trainer.train()
# Out:
# c:\Users\paish\anaconda3\Lib\site-packages\transformers\optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 trainer.train()
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\trainer.py:1633, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1628     self.model_wrapped = self.model
#    1630 inner_training_loop = find_executable_batch_size(
#    1631     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1632 )
# -> 1633 return inner_training_loop(
#    1634     args=args,
#    1635     resume_from_checkpoint=resume_from_checkpoint,
#    1636     trial=trial,
#    1637     ignore_keys_for_eval=ignore_keys_for_eval,
#    1638 )
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\trainer.py:1902, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1900         tr_loss_step = self.training_step(model, inputs)
#    1901 else:
# -> 1902     tr_loss_step = self.training_step(model, inputs)
#    1904 if (
#    1905     args.logging_nan_inf_filter
#    1906     and not is_torch_tpu_available()
#    1907     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1908 ):
#    1909     # if loss is nan or inf simply add the average of previous logged losses
#    1910     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\trainer.py:2645, in Trainer.training_step(self, model, inputs)
#    2642     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2644 with self.compute_loss_context_manager():
# -> 2645     loss = self.compute_loss(model, inputs)
#    2647 if self.args.n_gpu > 1:
#    2648     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\trainer.py:2677, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2675 else:
#    2676     labels = None
# -> 2677 outputs = model(**inputs)
#    2678 # Save past state if it exists
#    2679 # TODO: this needs to be fixed and made cleaner later.
#    2680 if self.args.past_index >= 0:
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1667, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1664 # Encode if needed (training, first prediction pass)
#    1665 if encoder_outputs is None:
#    1666     # Convert encoder inputs in embeddings if needed
# -> 1667     encoder_outputs = self.encoder(
#    1668         input_ids=input_ids,
#    1669         attention_mask=attention_mask,
#    1670         inputs_embeds=inputs_embeds,
#    1671         head_mask=head_mask,
#    1672         output_attentions=output_attentions,
#    1673         output_hidden_states=output_hidden_states,
#    1674         return_dict=return_dict,
#    1675     )
#    1676 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#    1677     encoder_outputs = BaseModelOutput(
#    1678         last_hidden_state=encoder_outputs[0],
#    1679         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1680         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1681     )
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:1074, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1061     layer_outputs = checkpoint(
#    1062         create_custom_forward(layer_module),
#    1063         hidden_states,
#    (...)
#    1071         None,  # past_key_value is always None with gradient checkpointing
#    1072     )
#    1073 else:
# -> 1074     layer_outputs = layer_module(
#    1075         hidden_states,
#    1076         attention_mask=extended_attention_mask,
#    1077         position_bias=position_bias,
#    1078         encoder_hidden_states=encoder_hidden_states,
#    1079         encoder_attention_mask=encoder_extended_attention_mask,
#    1080         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1081         layer_head_mask=layer_head_mask,
#    1082         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1083         past_key_value=past_key_value,
#    1084         use_cache=use_cache,
#    1085         output_attentions=output_attentions,
#    1086     )
#    1088 # layer_outputs is a tuple with:
#    1089 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1090 if use_cache is False:
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:745, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     742     attention_outputs = attention_outputs + cross_attention_outputs[2:]
#     744 # Apply Feed Forward layer
# --> 745 hidden_states = self.layer[-1](hidden_states)
#     747 # clamp inf values to enable fp16 training
#     748 if hidden_states.dtype == torch.float16 and torch.isinf(hidden_states).any():
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:343, in T5LayerFF.forward(self, hidden_states)
#     341 def forward(self, hidden_states):
#     342     forwarded_states = self.layer_norm(hidden_states)
# --> 343     forwarded_states = self.DenseReluDense(forwarded_states)
#     344     hidden_states = hidden_states + self.dropout(forwarded_states)
#     345     return hidden_states
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\transformers\models\t5\modeling_t5.py:326, in T5DenseGatedActDense.forward(self, hidden_states)
#     319 if (
#     320     isinstance(self.wo.weight, torch.Tensor)
#     321     and hidden_states.dtype != self.wo.weight.dtype
#     322     and self.wo.weight.dtype != torch.int8
#     323 ):
#     324     hidden_states = hidden_states.to(self.wo.weight.dtype)
# --> 326 hidden_states = self.wo(hidden_states)
#     327 return hidden_states
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\paish\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# Training a fully fine-tuned version of the model would take a few hours on a GPU. To save time, download a checkpoint of the fully fine-tuned model to use in the rest of this notebook. This fully fine-tuned model will also be referred to as the **instruct model** in this lab.

# %%
# !aws s3 cp --recursive s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/ ./flan-dialogue-summary-checkpoint/
# Out:
# ^C
# Completed 142 Bytes/2.8 GiB (209 Bytes/s) with 8 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/generation_config.json to flan-dialogue-summary-checkpoint\generation_config.json
# Completed 142 Bytes/2.8 GiB (209 Bytes/s) with 7 file(s) remaining
# Completed 3.7 KiB/2.8 GiB (5.0 KiB/s) with 7 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/training_args.bin to flan-dialogue-summary-checkpoint\training_args.bin
# Completed 3.7 KiB/2.8 GiB (5.0 KiB/s) with 6 file(s) remaining
# Completed 5.2 KiB/2.8 GiB (6.9 KiB/s) with 6 file(s) remaining
# Completed 14.9 KiB/2.8 GiB (19.6 KiB/s) with 6 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/trainer_state.json to flan-dialogue-summary-checkpoint\trainer_state.json
# Completed 14.9 KiB/2.8 GiB (19.6 KiB/s) with 5 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/config.json to flan-dialogue-summary-checkpoint\config.json
# Completed 14.9 KiB/2.8 GiB (19.6 KiB/s) with 4 file(s) remaining
# Completed 29.1 KiB/2.8 GiB (37.3 KiB/s) with 4 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/rng_state.pth to flan-dialogue-summary-checkpoint\rng_state.pth
# Completed 29.1 KiB/2.8 GiB (37.3 KiB/s) with 3 file(s) remaining
# Completed 285.1 KiB/2.8 GiB (343.4 KiB/s) with 3 file(s) remaining
# Completed 541.1 KiB/2.8 GiB (626.3 KiB/s) with 3 file(s) remaining
# Completed 797.1 KiB/2.8 GiB (913.4 KiB/s) with 3 file(s) remaining
# Completed 1.0 MiB/2.8 GiB (1.2 MiB/s) with 3 file(s) remaining
# Completed 1.0 MiB/2.8 GiB (1.2 MiB/s) with 3 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/scheduler.pt to flan-dialogue-summary-checkpoint\scheduler.pt
# Completed 1.0 MiB/2.8 GiB (1.2 MiB/s) with 2 file(s) remaining
# Completed 1.3 MiB/2.8 GiB (1.4 MiB/s) with 2 file(s) remaining
# Completed 1.5 MiB/2.8 GiB (1.7 MiB/s) with 2 file(s) remaining
# Completed 1.8 MiB/2.8 GiB (1.9 MiB/s) with 2 file(s) remaining
# Completed 2.0 MiB/2.8 GiB (2.2 MiB/s) with 2 file(s) remaining
# Completed 2.3 MiB/2.8 GiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 2.5 MiB/2.8 GiB (2.7 MiB/s) with 2 file(s) remaining
# Completed 2.8 MiB/2.8 GiB (2.9 MiB/s) with 2 file(s) remaining
# Completed 3.0 MiB/2.8 GiB (3.1 MiB/s) with 2 file(s) remaining
# Completed 3.3 MiB/2.8 GiB (3.3 MiB/s) with 2 file(s) remaining
# Completed 3.5 MiB/2.8 GiB (3.5 MiB/s) with 2 file(s) remaining
# Completed 3.8 MiB/2.8 GiB (3.7 MiB/s) with 2 file(s) remaining
# Completed 4.0 MiB/2.8 GiB (4.0 MiB/s) with 2 file(s) remaining
# Completed 4.3 MiB/2.8 GiB (4.2 MiB/s) with 2 file(s) remaining
# Completed 4.5 MiB/2.8 GiB (4.4 MiB/s) with 2 file(s) remaining
# Completed 4.8 MiB/2.8 GiB (4.6 MiB/s) with 2 file(s) remaining
# Completed 5.0 MiB/2.8 GiB (4.7 MiB/s) with 2 file(s) remaining
# Completed 5.3 MiB/2.8 GiB (4.9 MiB/s) with 2 file(s) remaining
# Completed 5.5 MiB/2.8 GiB (5.1 MiB/s) with 2 file(s) remaining
# Completed 5.8 MiB/2.8 GiB (5.3 MiB/s) with 2 file(s) remaining
# Completed 6.0 MiB/2.8 GiB (5.5 MiB/s) with 2 file(s) remaining
# Completed 6.3 MiB/2.8 GiB (5.7 MiB/s) with 2 file(s) remaining
# Completed 6.5 MiB/2.8 GiB (5.9 MiB/s) with 2 file(s) remaining
# Completed 6.8 MiB/2.8 GiB (6.0 MiB/s) with 2 file(s) remaining
# Completed 7.0 MiB/2.8 GiB (6.2 MiB/s) with 2 file(s) remaining
# Completed 7.3 MiB/2.8 GiB (6.4 MiB/s) with 2 file(s) remaining
# Completed 7.5 MiB/2.8 GiB (6.6 MiB/s) with 2 file(s) remaining
# Completed 7.8 MiB/2.8 GiB (6.7 MiB/s) with 2 file(s) remaining
# Completed 8.0 MiB/2.8 GiB (6.8 MiB/s) with 2 file(s) remaining
# Completed 8.3 MiB/2.8 GiB (7.0 MiB/s) with 2 file(s) remaining
# Completed 8.5 MiB/2.8 GiB (7.2 MiB/s) with 2 file(s) remaining
# Completed 8.8 MiB/2.8 GiB (7.3 MiB/s) with 2 file(s) remaining
# Completed 9.0 MiB/2.8 GiB (7.5 MiB/s) with 2 file(s) remaining
# Completed 9.3 MiB/2.8 GiB (7.6 MiB/s) with 2 file(s) remaining
# Completed 9.5 MiB/2.8 GiB (7.7 MiB/s) with 2 file(s) remaining
# Completed 9.8 MiB/2.8 GiB (7.7 MiB/s) with 2 file(s) remaining
# Completed 10.0 MiB/2.8 GiB (7.8 MiB/s) with 2 file(s) remaining
# Completed 10.3 MiB/2.8 GiB (8.0 MiB/s) with 2 file(s) remaining
# Completed 10.5 MiB/2.8 GiB (8.1 MiB/s) with 2 file(s) remaining
# Completed 10.8 MiB/2.8 GiB (8.2 MiB/s) with 2 file(s) remaining
# Completed 11.0 MiB/2.8 GiB (8.3 MiB/s) with 2 file(s) remaining
# Completed 11.3 MiB/2.8 GiB (8.4 MiB/s) with 2 file(s) remaining
# Completed 11.5 MiB/2.8 GiB (8.6 MiB/s) with 2 file(s) remaining
# Completed 11.8 MiB/2.8 GiB (8.6 MiB/s) with 2 file(s) remaining
# Completed 12.0 MiB/2.8 GiB (8.8 MiB/s) with 2 file(s) remaining
# Completed 12.3 MiB/2.8 GiB (8.9 MiB/s) with 2 file(s) remaining
# Completed 12.5 MiB/2.8 GiB (9.0 MiB/s) with 2 file(s) remaining
# Completed 12.8 MiB/2.8 GiB (9.1 MiB/s) with 2 file(s) remaining
# Completed 13.0 MiB/2.8 GiB (9.2 MiB/s) with 2 file(s) remaining
# Completed 13.3 MiB/2.8 GiB (9.3 MiB/s) with 2 file(s) remaining
# Completed 13.5 MiB/2.8 GiB (9.4 MiB/s) with 2 file(s) remaining
# Completed 13.8 MiB/2.8 GiB (9.5 MiB/s) with 2 file(s) remaining
# Completed 14.0 MiB/2.8 GiB (9.7 MiB/s) with 2 file(s) remaining
# Completed 14.3 MiB/2.8 GiB (9.7 MiB/s) with 2 file(s) remaining
# Completed 14.5 MiB/2.8 GiB (9.8 MiB/s) with 2 file(s) remaining
# Completed 14.8 MiB/2.8 GiB (10.0 MiB/s) with 2 file(s) remaining
# Completed 15.0 MiB/2.8 GiB (10.1 MiB/s) with 2 file(s) remaining
# Completed 15.3 MiB/2.8 GiB (10.2 MiB/s) with 2 file(s) remaining
# Completed 15.5 MiB/2.8 GiB (10.2 MiB/s) with 2 file(s) remaining
# Completed 15.8 MiB/2.8 GiB (10.3 MiB/s) with 2 file(s) remaining
# Completed 16.0 MiB/2.8 GiB (10.3 MiB/s) with 2 file(s) remaining
# Completed 16.3 MiB/2.8 GiB (10.4 MiB/s) with 2 file(s) remaining
# Completed 16.5 MiB/2.8 GiB (10.4 MiB/s) with 2 file(s) remaining
# Completed 16.8 MiB/2.8 GiB (10.5 MiB/s) with 2 file(s) remaining
# Completed 17.0 MiB/2.8 GiB (10.7 MiB/s) with 2 file(s) remaining
# Completed 17.3 MiB/2.8 GiB (10.8 MiB/s) with 2 file(s) remaining
# Completed 17.5 MiB/2.8 GiB (10.9 MiB/s) with 2 file(s) remaining
# Completed 17.8 MiB/2.8 GiB (10.9 MiB/s) with 2 file(s) remaining
# Completed 18.0 MiB/2.8 GiB (11.0 MiB/s) with 2 file(s) remaining
# Completed 18.3 MiB/2.8 GiB (11.1 MiB/s) with 2 file(s) remaining
# Completed 18.5 MiB/2.8 GiB (11.2 MiB/s) with 2 file(s) remaining
# Completed 18.8 MiB/2.8 GiB (11.2 MiB/s) with 2 file(s) remaining
# Completed 19.0 MiB/2.8 GiB (11.4 MiB/s) with 2 file(s) remaining
# Completed 19.3 MiB/2.8 GiB (11.5 MiB/s) with 2 file(s) remaining
# Completed 19.5 MiB/2.8 GiB (11.6 MiB/s) with 2 file(s) remaining
# Completed 19.8 MiB/2.8 GiB (11.8 MiB/s) with 2 file(s) remaining
# Completed 20.0 MiB/2.8 GiB (11.9 MiB/s) with 2 file(s) remaining
# Completed 20.3 MiB/2.8 GiB (12.0 MiB/s) with 2 file(s) remaining
# Completed 20.5 MiB/2.8 GiB (12.0 MiB/s) with 2 file(s) remaining
# Completed 20.8 MiB/2.8 GiB (12.0 MiB/s) with 2 file(s) remaining
# Completed 21.0 MiB/2.8 GiB (12.1 MiB/s) with 2 file(s) remaining
# Completed 21.3 MiB/2.8 GiB (12.2 MiB/s) with 2 file(s) remaining
# Completed 21.5 MiB/2.8 GiB (12.1 MiB/s) with 2 file(s) remaining
# Completed 21.8 MiB/2.8 GiB (12.2 MiB/s) with 2 file(s) remaining
# Completed 22.0 MiB/2.8 GiB (12.2 MiB/s) with 2 file(s) remaining
# Completed 22.3 MiB/2.8 GiB (12.3 MiB/s) with 2 file(s) remaining
# Completed 22.5 MiB/2.8 GiB (12.4 MiB/s) with 2 file(s) remaining
# Completed 22.8 MiB/2.8 GiB (12.6 MiB/s) with 2 file(s) remaining
# Completed 23.0 MiB/2.8 GiB (12.7 MiB/s) with 2 file(s) remaining
# Completed 23.3 MiB/2.8 GiB (12.7 MiB/s) with 2 file(s) remaining
# Completed 23.5 MiB/2.8 GiB (12.8 MiB/s) with 2 file(s) remaining
# Completed 23.8 MiB/2.8 GiB (12.9 MiB/s) with 2 file(s) remaining
# Completed 24.0 MiB/2.8 GiB (13.0 MiB/s) with 2 file(s) remaining
# Completed 24.3 MiB/2.8 GiB (13.1 MiB/s) with 2 file(s) remaining
# Completed 24.5 MiB/2.8 GiB (13.2 MiB/s) with 2 file(s) remaining
# Completed 24.8 MiB/2.8 GiB (13.2 MiB/s) with 2 file(s) remaining
# Completed 25.0 MiB/2.8 GiB (13.3 MiB/s) with 2 file(s) remaining
# Completed 25.3 MiB/2.8 GiB (13.4 MiB/s) with 2 file(s) remaining
# Completed 25.5 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 25.8 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 26.0 MiB/2.8 GiB (13.6 MiB/s) with 2 file(s) remaining
# Completed 26.3 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 26.5 MiB/2.8 GiB (13.7 MiB/s) with 2 file(s) remaining
# Completed 26.8 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 27.0 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 27.3 MiB/2.8 GiB (13.6 MiB/s) with 2 file(s) remaining
# Completed 27.5 MiB/2.8 GiB (13.7 MiB/s) with 2 file(s) remaining
# Completed 27.8 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 28.0 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 28.3 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 28.5 MiB/2.8 GiB (13.5 MiB/s) with 2 file(s) remaining
# Completed 28.8 MiB/2.8 GiB (13.6 MiB/s) with 2 file(s) remaining
# Completed 29.0 MiB/2.8 GiB (13.7 MiB/s) with 2 file(s) remaining
# Completed 29.3 MiB/2.8 GiB (13.8 MiB/s) with 2 file(s) remaining
# Completed 29.5 MiB/2.8 GiB (13.9 MiB/s) with 2 file(s) remaining
# Completed 29.8 MiB/2.8 GiB (14.0 MiB/s) with 2 file(s) remaining
# Completed 30.0 MiB/2.8 GiB (14.0 MiB/s) with 2 file(s) remaining
# Completed 30.3 MiB/2.8 GiB (14.0 MiB/s) with 2 file(s) remaining
# Completed 30.5 MiB/2.8 GiB (14.1 MiB/s) with 2 file(s) remaining
# Completed 30.8 MiB/2.8 GiB (14.1 MiB/s) with 2 file(s) remaining
# Completed 31.0 MiB/2.8 GiB (14.3 MiB/s) with 2 file(s) remaining
# Completed 31.3 MiB/2.8 GiB (14.4 MiB/s) with 2 file(s) remaining
# Completed 31.5 MiB/2.8 GiB (14.4 MiB/s) with 2 file(s) remaining
# Completed 31.8 MiB/2.8 GiB (14.5 MiB/s) with 2 file(s) remaining
# Completed 32.0 MiB/2.8 GiB (14.6 MiB/s) with 2 file(s) remaining
# Completed 32.3 MiB/2.8 GiB (14.7 MiB/s) with 2 file(s) remaining
# Completed 32.5 MiB/2.8 GiB (14.7 MiB/s) with 2 file(s) remaining
# Completed 32.8 MiB/2.8 GiB (14.7 MiB/s) with 2 file(s) remaining
# Completed 33.0 MiB/2.8 GiB (14.8 MiB/s) with 2 file(s) remaining
# Completed 33.3 MiB/2.8 GiB (14.9 MiB/s) with 2 file(s) remaining
# Completed 33.5 MiB/2.8 GiB (15.0 MiB/s) with 2 file(s) remaining
# Completed 33.8 MiB/2.8 GiB (15.0 MiB/s) with 2 file(s) remaining
# Completed 34.0 MiB/2.8 GiB (15.0 MiB/s) with 2 file(s) remaining
# Completed 34.3 MiB/2.8 GiB (15.1 MiB/s) with 2 file(s) remaining
# Completed 34.5 MiB/2.8 GiB (15.1 MiB/s) with 2 file(s) remaining
# Completed 34.8 MiB/2.8 GiB (15.2 MiB/s) with 2 file(s) remaining
# Completed 35.0 MiB/2.8 GiB (15.1 MiB/s) with 2 file(s) remaining
# Completed 35.3 MiB/2.8 GiB (15.1 MiB/s) with 2 file(s) remaining
# Completed 35.5 MiB/2.8 GiB (15.2 MiB/s) with 2 file(s) remaining
# Completed 35.8 MiB/2.8 GiB (15.3 MiB/s) with 2 file(s) remaining
# Completed 36.0 MiB/2.8 GiB (15.4 MiB/s) with 2 file(s) remaining
# Completed 36.3 MiB/2.8 GiB (15.4 MiB/s) with 2 file(s) remaining
# Completed 36.5 MiB/2.8 GiB (15.4 MiB/s) with 2 file(s) remaining
# Completed 36.8 MiB/2.8 GiB (15.4 MiB/s) with 2 file(s) remaining
# Completed 37.0 MiB/2.8 GiB (15.5 MiB/s) with 2 file(s) remaining
# Completed 37.3 MiB/2.8 GiB (15.6 MiB/s) with 2 file(s) remaining
# Completed 37.5 MiB/2.8 GiB (15.6 MiB/s) with 2 file(s) remaining
# Completed 37.8 MiB/2.8 GiB (15.6 MiB/s) with 2 file(s) remaining
# Completed 38.0 MiB/2.8 GiB (15.7 MiB/s) with 2 file(s) remaining
# Completed 38.3 MiB/2.8 GiB (15.7 MiB/s) with 2 file(s) remaining
# Completed 38.5 MiB/2.8 GiB (15.7 MiB/s) with 2 file(s) remaining
# Completed 38.8 MiB/2.8 GiB (15.8 MiB/s) with 2 file(s) remaining
# Completed 39.0 MiB/2.8 GiB (15.8 MiB/s) with 2 file(s) remaining
# Completed 39.3 MiB/2.8 GiB (15.9 MiB/s) with 2 file(s) remaining
# Completed 39.5 MiB/2.8 GiB (15.8 MiB/s) with 2 file(s) remaining
# Completed 39.8 MiB/2.8 GiB (15.9 MiB/s) with 2 file(s) remaining
# Completed 40.0 MiB/2.8 GiB (15.9 MiB/s) with 2 file(s) remaining
# Completed 40.3 MiB/2.8 GiB (16.0 MiB/s) with 2 file(s) remaining
# Completed 40.5 MiB/2.8 GiB (16.0 MiB/s) with 2 file(s) remaining
# Completed 40.8 MiB/2.8 GiB (16.1 MiB/s) with 2 file(s) remaining
# Completed 41.0 MiB/2.8 GiB (16.1 MiB/s) with 2 file(s) remaining
# Completed 41.3 MiB/2.8 GiB (16.1 MiB/s) with 2 file(s) remaining
# Completed 41.5 MiB/2.8 GiB (16.1 MiB/s) with 2 file(s) remaining
# Completed 41.8 MiB/2.8 GiB (16.2 MiB/s) with 2 file(s) remaining
# Completed 42.0 MiB/2.8 GiB (16.1 MiB/s) with 2 file(s) remaining
# Completed 42.3 MiB/2.8 GiB (16.2 MiB/s) with 2 file(s) remaining
# Completed 42.5 MiB/2.8 GiB (16.2 MiB/s) with 2 file(s) remaining
# Completed 42.8 MiB/2.8 GiB (16.2 MiB/s) with 2 file(s) remaining
# Completed 43.0 MiB/2.8 GiB (16.2 MiB/s) with 2 file(s) remaining
# Completed 43.3 MiB/2.8 GiB (16.3 MiB/s) with 2 file(s) remaining
# Completed 43.5 MiB/2.8 GiB (16.3 MiB/s) with 2 file(s) remaining
# Completed 43.8 MiB/2.8 GiB (16.4 MiB/s) with 2 file(s) remaining
# Completed 44.0 MiB/2.8 GiB (16.4 MiB/s) with 2 file(s) remaining
# Completed 44.3 MiB/2.8 GiB (16.4 MiB/s) with 2 file(s) remaining
# Completed 44.5 MiB/2.8 GiB (16.5 MiB/s) with 2 file(s) remaining
# Completed 44.8 MiB/2.8 GiB (16.5 MiB/s) with 2 file(s) remaining
# Completed 45.0 MiB/2.8 GiB (16.6 MiB/s) with 2 file(s) remaining
# Completed 45.3 MiB/2.8 GiB (16.5 MiB/s) with 2 file(s) remaining
# Completed 45.5 MiB/2.8 GiB (16.6 MiB/s) with 2 file(s) remaining
# Completed 45.8 MiB/2.8 GiB (16.5 MiB/s) with 2 file(s) remaining
# Completed 46.0 MiB/2.8 GiB (16.6 MiB/s) with 2 file(s) remaining
# Completed 46.3 MiB/2.8 GiB (16.6 MiB/s) with 2 file(s) remaining
# Completed 46.5 MiB/2.8 GiB (16.7 MiB/s) with 2 file(s) remaining
# Completed 46.8 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 47.0 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 47.3 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 47.5 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 47.8 MiB/2.8 GiB (16.9 MiB/s) with 2 file(s) remaining
# Completed 48.0 MiB/2.8 GiB (16.9 MiB/s) with 2 file(s) remaining
# Completed 48.3 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 48.5 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 48.8 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 49.0 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 49.3 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 49.5 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 49.8 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 50.0 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 50.3 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 50.5 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 50.8 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 51.0 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 51.3 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 51.5 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 51.8 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 52.0 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 52.3 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 52.5 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 52.8 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 53.0 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 53.3 MiB/2.8 GiB (16.8 MiB/s) with 2 file(s) remaining
# Completed 53.5 MiB/2.8 GiB (16.9 MiB/s) with 2 file(s) remaining
# Completed 53.8 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 54.0 MiB/2.8 GiB (17.0 MiB/s) with 2 file(s) remaining
# Completed 54.3 MiB/2.8 GiB (17.1 MiB/s) with 2 file(s) remaining
# Completed 54.5 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 54.8 MiB/2.8 GiB (17.2 MiB/s) with 2 file(s) remaining
# Completed 55.0 MiB/2.8 GiB (17.3 MiB/s) with 2 file(s) remaining
# Completed 55.3 MiB/2.8 GiB (17.4 MiB/s) with 2 file(s) remaining
# Completed 55.5 MiB/2.8 GiB (17.4 MiB/s) with 2 file(s) remaining
# Completed 55.8 MiB/2.8 GiB (17.5 MiB/s) with 2 file(s) remaining
# Completed 56.0 MiB/2.8 GiB (17.6 MiB/s) with 2 file(s) remaining
# Completed 56.3 MiB/2.8 GiB (17.7 MiB/s) with 2 file(s) remaining
# Completed 56.5 MiB/2.8 GiB (17.7 MiB/s) with 2 file(s) remaining
# Completed 56.8 MiB/2.8 GiB (17.8 MiB/s) with 2 file(s) remaining
# Completed 57.0 MiB/2.8 GiB (17.8 MiB/s) with 2 file(s) remaining
# Completed 57.3 MiB/2.8 GiB (17.9 MiB/s) with 2 file(s) remaining
# Completed 57.5 MiB/2.8 GiB (17.9 MiB/s) with 2 file(s) remaining
# Completed 57.8 MiB/2.8 GiB (17.9 MiB/s) with 2 file(s) remaining
# Completed 58.0 MiB/2.8 GiB (18.0 MiB/s) with 2 file(s) remaining
# Completed 58.3 MiB/2.8 GiB (18.0 MiB/s) with 2 file(s) remaining
# Completed 58.5 MiB/2.8 GiB (18.0 MiB/s) with 2 file(s) remaining
# Completed 58.8 MiB/2.8 GiB (18.1 MiB/s) with 2 file(s) remaining
# Completed 59.0 MiB/2.8 GiB (18.2 MiB/s) with 2 file(s) remaining
# Completed 59.3 MiB/2.8 GiB (18.1 MiB/s) with 2 file(s) remaining
# Completed 59.5 MiB/2.8 GiB (18.1 MiB/s) with 2 file(s) remaining
# Completed 59.8 MiB/2.8 GiB (18.2 MiB/s) with 2 file(s) remaining
# Completed 60.0 MiB/2.8 GiB (18.2 MiB/s) with 2 file(s) remaining
# Completed 60.3 MiB/2.8 GiB (18.3 MiB/s) with 2 file(s) remaining
# Completed 60.5 MiB/2.8 GiB (18.3 MiB/s) with 2 file(s) remaining
# Completed 60.8 MiB/2.8 GiB (18.4 MiB/s) with 2 file(s) remaining
# Completed 61.0 MiB/2.8 GiB (18.4 MiB/s) with 2 file(s) remaining
# Completed 61.3 MiB/2.8 GiB (18.4 MiB/s) with 2 file(s) remaining
# Completed 61.5 MiB/2.8 GiB (18.4 MiB/s) with 2 file(s) remaining
# Completed 61.8 MiB/2.8 GiB (18.4 MiB/s) with 2 file(s) remaining
# Completed 62.0 MiB/2.8 GiB (18.5 MiB/s) with 2 file(s) remaining
# Completed 62.3 MiB/2.8 GiB (18.5 MiB/s) with 2 file(s) remaining
# Completed 62.5 MiB/2.8 GiB (18.6 MiB/s) with 2 file(s) remaining
# Completed 62.8 MiB/2.8 GiB (18.6 MiB/s) with 2 file(s) remaining
# Completed 63.0 MiB/2.8 GiB (18.6 MiB/s) with 2 file(s) remaining
# Completed 63.3 MiB/2.8 GiB (18.7 MiB/s) with 2 file(s) remaining
# Completed 63.5 MiB/2.8 GiB (18.7 MiB/s) with 2 file(s) remaining
# Completed 63.8 MiB/2.8 GiB (18.8 MiB/s) with 2 file(s) remaining
# Completed 64.0 MiB/2.8 GiB (18.7 MiB/s) with 2 file(s) remaining
# Completed 64.3 MiB/2.8 GiB (18.8 MiB/s) with 2 file(s) remaining
# Completed 64.5 MiB/2.8 GiB (18.8 MiB/s) with 2 file(s) remaining
# Completed 64.8 MiB/2.8 GiB (18.9 MiB/s) with 2 file(s) remaining
# Completed 65.0 MiB/2.8 GiB (18.9 MiB/s) with 2 file(s) remaining
# Completed 65.3 MiB/2.8 GiB (19.0 MiB/s) with 2 file(s) remaining
# Completed 65.5 MiB/2.8 GiB (18.9 MiB/s) with 2 file(s) remaining
# Completed 65.8 MiB/2.8 GiB (19.0 MiB/s) with 2 file(s) remaining
# Completed 66.0 MiB/2.8 GiB (19.0 MiB/s) with 2 file(s) remaining
# Completed 66.3 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 66.5 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 66.8 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 67.0 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 67.3 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 67.5 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 67.8 MiB/2.8 GiB (19.1 MiB/s) with 2 file(s) remaining
# Completed 68.0 MiB/2.8 GiB (19.2 MiB/s) with 2 file(s) remaining
# Completed 68.3 MiB/2.8 GiB (19.2 MiB/s) with 2 file(s) remaining
# Completed 68.5 MiB/2.8 GiB (19.3 MiB/s) with 2 file(s) remaining
# Completed 68.8 MiB/2.8 GiB (19.3 MiB/s) with 2 file(s) remaining
# Completed 69.0 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 69.3 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 69.5 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 69.8 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 70.0 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 70.3 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 70.5 MiB/2.8 GiB (19.4 MiB/s) with 2 file(s) remaining
# Completed 70.8 MiB/2.8 GiB (19.5 MiB/s) with 2 file(s) remaining
# Completed 71.0 MiB/2.8 GiB (19.5 MiB/s) with 2 file(s) remaining
# Completed 71.3 MiB/2.8 GiB (19.6 MiB/s) with 2 file(s) remaining
# Completed 71.5 MiB/2.8 GiB (19.6 MiB/s) with 2 file(s) remaining
# Completed 71.8 MiB/2.8 GiB (19.7 MiB/s) with 2 file(s) remaining
# Completed 72.0 MiB/2.8 GiB (19.7 MiB/s) with 2 file(s) remaining
# Completed 72.3 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 72.5 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 72.8 MiB/2.8 GiB (19.7 MiB/s) with 2 file(s) remaining
# Completed 73.0 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 73.3 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 73.5 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 73.8 MiB/2.8 GiB (19.8 MiB/s) with 2 file(s) remaining
# Completed 74.0 MiB/2.8 GiB (19.9 MiB/s) with 2 file(s) remaining
# Completed 74.3 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 74.5 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 74.8 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 75.0 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 75.3 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 75.5 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 75.8 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 76.0 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 76.3 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 76.5 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 76.8 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 77.0 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 77.3 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 77.5 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 77.8 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 78.0 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 78.3 MiB/2.8 GiB (20.0 MiB/s) with 2 file(s) remaining
# Completed 78.5 MiB/2.8 GiB (20.1 MiB/s) with 2 file(s) remaining
# Completed 78.8 MiB/2.8 GiB (20.2 MiB/s) with 2 file(s) remaining
# Completed 79.0 MiB/2.8 GiB (20.2 MiB/s) with 2 file(s) remaining
# Completed 79.3 MiB/2.8 GiB (20.3 MiB/s) with 2 file(s) remaining
# Completed 79.5 MiB/2.8 GiB (20.3 MiB/s) with 2 file(s) remaining
# Completed 79.8 MiB/2.8 GiB (20.4 MiB/s) with 2 file(s) remaining
# Completed 80.0 MiB/2.8 GiB (20.4 MiB/s) with 2 file(s) remaining
# Completed 80.3 MiB/2.8 GiB (20.4 MiB/s) with 2 file(s) remaining
# Completed 80.5 MiB/2.8 GiB (20.5 MiB/s) with 2 file(s) remaining
# Completed 80.8 MiB/2.8 GiB (20.4 MiB/s) with 2 file(s) remaining
# Completed 81.0 MiB/2.8 GiB (20.5 MiB/s) with 2 file(s) remaining
# Completed 81.3 MiB/2.8 GiB (20.5 MiB/s) with 2 file(s) remaining
# Completed 81.5 MiB/2.8 GiB (20.5 MiB/s) with 2 file(s) remaining
# Completed 81.8 MiB/2.8 GiB (20.6 MiB/s) with 2 file(s) remaining
# Completed 82.0 MiB/2.8 GiB (20.6 MiB/s) with 2 file(s) remaining
# Completed 82.3 MiB/2.8 GiB (20.6 MiB/s) with 2 file(s) remaining
# Completed 82.5 MiB/2.8 GiB (20.6 MiB/s) with 2 file(s) remaining
# Completed 82.8 MiB/2.8 GiB (20.7 MiB/s) with 2 file(s) remaining
# Completed 83.0 MiB/2.8 GiB (20.7 MiB/s) with 2 file(s) remaining
# Completed 83.3 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 83.5 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 83.8 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 84.0 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 84.3 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 84.5 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 84.8 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 85.0 MiB/2.8 GiB (20.9 MiB/s) with 2 file(s) remaining
# Completed 85.3 MiB/2.8 GiB (20.8 MiB/s) with 2 file(s) remaining
# Completed 85.5 MiB/2.8 GiB (20.9 MiB/s) with 2 file(s) remaining
# Completed 85.8 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 86.0 MiB/2.8 GiB (20.9 MiB/s) with 2 file(s) remaining
# Completed 86.3 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 86.5 MiB/2.8 GiB (20.9 MiB/s) with 2 file(s) remaining
# Completed 86.8 MiB/2.8 GiB (20.9 MiB/s) with 2 file(s) remaining
# Completed 87.0 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 87.3 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 87.5 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 87.8 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 88.0 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 88.3 MiB/2.8 GiB (21.0 MiB/s) with 2 file(s) remaining
# Completed 88.5 MiB/2.8 GiB (21.1 MiB/s) with 2 file(s) remaining
# Completed 88.8 MiB/2.8 GiB (21.1 MiB/s) with 2 file(s) remaining
# Completed 89.0 MiB/2.8 GiB (21.2 MiB/s) with 2 file(s) remaining
# Completed 89.3 MiB/2.8 GiB (21.2 MiB/s) with 2 file(s) remaining
# Completed 89.5 MiB/2.8 GiB (21.2 MiB/s) with 2 file(s) remaining
# Completed 89.8 MiB/2.8 GiB (21.2 MiB/s) with 2 file(s) remaining
# Completed 90.0 MiB/2.8 GiB (21.3 MiB/s) with 2 file(s) remaining
# Completed 90.3 MiB/2.8 GiB (21.3 MiB/s) with 2 file(s) remaining
# Completed 90.5 MiB/2.8 GiB (21.3 MiB/s) with 2 file(s) remaining
# Completed 90.8 MiB/2.8 GiB (21.4 MiB/s) with 2 file(s) remaining
# Completed 91.0 MiB/2.8 GiB (21.4 MiB/s) with 2 file(s) remaining
# Completed 91.3 MiB/2.8 GiB (21.4 MiB/s) with 2 file(s) remaining
# Completed 91.5 MiB/2.8 GiB (21.4 MiB/s) with 2 file(s) remaining
# Completed 91.8 MiB/2.8 GiB (21.4 MiB/s) with 2 file(s) remaining
# Completed 92.0 MiB/2.8 GiB (21.5 MiB/s) with 2 file(s) remaining
# Completed 92.3 MiB/2.8 GiB (21.5 MiB/s) with 2 file(s) remaining
# Completed 92.5 MiB/2.8 GiB (21.5 MiB/s) with 2 file(s) remaining
# Completed 92.8 MiB/2.8 GiB (21.5 MiB/s) with 2 file(s) remaining
# Completed 93.0 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 93.3 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 93.5 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 93.8 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 94.0 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 94.3 MiB/2.8 GiB (21.5 MiB/s) with 2 file(s) remaining
# Completed 94.5 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 94.8 MiB/2.8 GiB (21.6 MiB/s) with 2 file(s) remaining
# Completed 95.0 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 95.3 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 95.5 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 95.8 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 96.0 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 96.3 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 96.5 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 96.8 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 97.0 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 97.3 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 97.5 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 97.8 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 98.0 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 98.3 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 98.5 MiB/2.8 GiB (21.7 MiB/s) with 2 file(s) remaining
# Completed 98.8 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 99.0 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 99.3 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 99.5 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 99.8 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 100.0 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 100.3 MiB/2.8 GiB (21.8 MiB/s) with 2 file(s) remaining
# Completed 100.5 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 100.8 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 101.0 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 101.3 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 101.5 MiB/2.8 GiB (22.0 MiB/s) with 2 file(s) remaining
# Completed 101.8 MiB/2.8 GiB (22.0 MiB/s) with 2 file(s) remaining
# Completed 102.0 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 102.3 MiB/2.8 GiB (21.9 MiB/s) with 2 file(s) remaining
# Completed 102.5 MiB/2.8 GiB (22.0 MiB/s) with 2 file(s) remaining
# Completed 102.8 MiB/2.8 GiB (22.0 MiB/s) with 2 file(s) remaining
# Completed 103.0 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 103.3 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 103.5 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 103.8 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 104.0 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 104.3 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 104.5 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 104.8 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 105.0 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 105.3 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 105.5 MiB/2.8 GiB (22.1 MiB/s) with 2 file(s) remaining
# Completed 105.8 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 106.0 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 106.3 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 106.5 MiB/2.8 GiB (22.2 MiB/s) with 2 file(s) remaining
# Completed 106.8 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 107.0 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 107.3 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 107.5 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 107.8 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 108.0 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 108.3 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 108.5 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 108.8 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 109.0 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 109.3 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 109.5 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 109.8 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 110.0 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 110.3 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 110.5 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 110.8 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 111.0 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 111.3 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 111.5 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 111.8 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 112.0 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 112.3 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 112.5 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 112.8 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 113.0 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 113.3 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 113.5 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 113.8 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 114.0 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 114.3 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 114.5 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 114.8 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 115.0 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 115.3 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 115.5 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 115.8 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 116.0 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 116.3 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 116.5 MiB/2.8 GiB (22.3 MiB/s) with 2 file(s) remaining
# Completed 116.8 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 117.0 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 117.3 MiB/2.8 GiB (22.4 MiB/s) with 2 file(s) remaining
# Completed 117.5 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 117.8 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 118.0 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 118.3 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 118.5 MiB/2.8 GiB (22.5 MiB/s) with 2 file(s) remaining
# Completed 118.8 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 119.0 MiB/2.8 GiB (22.6 MiB/s) with 2 file(s) remaining
# Completed 119.3 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 119.5 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 119.8 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 120.0 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 120.3 MiB/2.8 GiB (22.7 MiB/s) with 2 file(s) remaining
# Completed 120.5 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 120.8 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 121.0 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 121.3 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 121.5 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 121.8 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 122.0 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 122.3 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 122.5 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 122.8 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 123.0 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 123.3 MiB/2.8 GiB (22.8 MiB/s) with 2 file(s) remaining
# Completed 123.5 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 123.8 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 124.0 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 124.3 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 124.5 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 124.8 MiB/2.8 GiB (22.9 MiB/s) with 2 file(s) remaining
# Completed 125.0 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 125.3 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 125.5 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 125.8 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 126.0 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 126.3 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 126.5 MiB/2.8 GiB (23.0 MiB/s) with 2 file(s) remaining
# Completed 126.8 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 127.0 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 127.3 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 127.5 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 127.8 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 128.0 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 128.3 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 128.5 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 128.8 MiB/2.8 GiB (23.1 MiB/s) with 2 file(s) remaining
# Completed 129.0 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 129.3 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 129.5 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 129.8 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 130.0 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 130.3 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 130.5 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 130.8 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 131.0 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 131.3 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 131.5 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 131.8 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 132.0 MiB/2.8 GiB (23.2 MiB/s) with 2 file(s) remaining
# Completed 132.3 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 132.5 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 132.8 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 133.0 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 133.3 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 133.5 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 133.8 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 134.0 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 134.3 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 134.5 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 134.8 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 135.0 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 135.3 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 135.5 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 135.8 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 136.0 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 136.3 MiB/2.8 GiB (23.3 MiB/s) with 2 file(s) remaining
# Completed 136.5 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 136.8 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 137.0 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 137.3 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 137.5 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 137.8 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 138.0 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 138.3 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 138.5 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 138.8 MiB/2.8 GiB (23.4 MiB/s) with 2 file(s) remaining
# Completed 139.0 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 139.3 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 139.5 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 139.8 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 140.0 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 140.3 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 140.5 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 140.8 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 141.0 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 141.3 MiB/2.8 GiB (23.5 MiB/s) with 2 file(s) remaining
# Completed 141.5 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 141.8 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 142.0 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 142.3 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 142.5 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 142.8 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 143.0 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 143.3 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 143.5 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 143.8 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 144.0 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 144.3 MiB/2.8 GiB (23.6 MiB/s) with 2 file(s) remaining
# Completed 144.5 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 144.8 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 145.0 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 145.3 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 145.5 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 145.8 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 146.0 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 146.3 MiB/2.8 GiB (23.7 MiB/s) with 2 file(s) remaining
# Completed 146.5 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 146.8 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 147.0 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 147.3 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 147.5 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 147.8 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 148.0 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 148.3 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 148.5 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 148.8 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 149.0 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 149.3 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 149.5 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 149.8 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 150.0 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 150.3 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 150.5 MiB/2.8 GiB (23.8 MiB/s) with 2 file(s) remaining
# Completed 150.8 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 151.0 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 151.3 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 151.5 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 151.8 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 152.0 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 152.3 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 152.5 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 152.8 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 153.0 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 153.3 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 153.5 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 153.8 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 154.0 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 154.3 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 154.5 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 154.8 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 155.0 MiB/2.8 GiB (23.9 MiB/s) with 2 file(s) remaining
# Completed 155.3 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 155.5 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 155.8 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 156.0 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 156.3 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 156.5 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 156.8 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 157.0 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 157.3 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 157.5 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 157.8 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 158.0 MiB/2.8 GiB (24.0 MiB/s) with 2 file(s) remaining
# Completed 158.3 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 158.5 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 158.8 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 159.0 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 159.3 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 159.5 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 159.8 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 160.0 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 160.3 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 160.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 160.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 161.0 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 161.3 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 161.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 161.8 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 162.0 MiB/2.8 GiB (24.1 MiB/s) with 2 file(s) remaining
# Completed 162.3 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 162.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 162.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 163.0 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 163.3 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 163.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 163.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 164.0 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 164.3 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 164.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 164.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 165.0 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 165.3 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 165.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 165.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 166.0 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 166.3 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 166.5 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 166.8 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 167.0 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 167.3 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 167.5 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 167.8 MiB/2.8 GiB (24.2 MiB/s) with 2 file(s) remaining
# Completed 168.0 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 168.3 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 168.5 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 168.8 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 169.0 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 169.3 MiB/2.8 GiB (24.3 MiB/s) with 2 file(s) remaining
# Completed 169.5 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 169.8 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 170.0 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 170.3 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 170.5 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 170.8 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 171.0 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 171.3 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 171.5 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 171.8 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 172.0 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 172.3 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 172.5 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 172.8 MiB/2.8 GiB (24.4 MiB/s) with 2 file(s) remaining
# Completed 173.0 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 173.3 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 173.5 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 173.8 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 174.0 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 174.3 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 174.5 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 174.8 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 175.0 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 175.3 MiB/2.8 GiB (24.5 MiB/s) with 2 file(s) remaining
# Completed 175.5 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 175.8 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 176.0 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 176.3 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 176.5 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 176.8 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 177.0 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# Completed 177.3 MiB/2.8 GiB (24.6 MiB/s) with 2 file(s) remaining
# ...
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.7 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (30.0 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.9 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.8 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.8 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.8 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.8 MiB/s) with 1 file(s) remaining
# Completed 2.8 GiB/2.8 GiB (29.8 MiB/s) with 1 file(s) remaining
# download: s3://dlai-generative-ai/models/flan-dialogue-summary-checkpoint/optimizer.pt to flan-dialogue-summary-checkpoint\optimizer.pt

# %% [markdown]
# The size of the downloaded instruct model is approximately 1GB.

# %%
# !ls -alh ./flan-dialogue-summary-checkpoint/pytorch_model.bin

# %% [markdown]
# Create an instance of the `AutoModelForSeq2SeqLM` class for the instruct model:

# %%
instruct_model = AutoModelForSeq2SeqLM.from_pretrained("./flan-dialogue-summary-checkpoint", torch_dtype=torch.bfloat16)

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Evaluate the Model Qualitatively (Human Evaluation)
#
# As with many GenAI applications, a qualitative approach where you ask yourself the question "Is my model behaving the way it is supposed to?" is usually a good starting point. In the example below (the same one we started this notebook with), you can see how the fine-tuned model is able to create a reasonable summary of the dialogue compared to the original inability to understand what is being asked of the model.

# %%
index = 200
dialogue = dataset['test'][index]['dialogue']
human_baseline_summary = dataset['test'][index]['summary']

prompt = f"""
Summarize the following conversation.

{dialogue}

Summary:
"""

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

print(dash_line)
print(f'BASELINE HUMAN SUMMARY:\n{human_baseline_summary}')
print(dash_line)
print(f'ORIGINAL MODEL:\n{original_model_text_output}')
print(dash_line)
print(f'INSTRUCT MODEL:\n{instruct_model_text_output}')

# %% [markdown]
# <a name='2.4'></a>
# ### 2.4 - Evaluate the Model Quantitatively (with ROUGE Metric)
#
# The [ROUGE metric](https://en.wikipedia.org/wiki/ROUGE_(metric)) helps quantify the validity of summarizations produced by models. It compares summarizations to a "baseline" summary which is usually created by a human. While not perfect, it does indicate the overall increase in summarization effectiveness that we have accomplished by fine-tuning.

# %%
rouge = evaluate.load('rouge')

# %% [markdown]
# Generate the outputs for the sample of the test dataset (only 10 dialogues and summaries to save time), and save the results.

# %%
dialogues = dataset['test'][0:10]['dialogue']
human_baseline_summaries = dataset['test'][0:10]['summary']

original_model_summaries = []
instruct_model_summaries = []

for _, dialogue in enumerate(dialogues):
    prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids

    original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)
    original_model_summaries.append(original_model_text_output)

    instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)
    instruct_model_summaries.append(instruct_model_text_output)
    
zipped_summaries = list(zip(human_baseline_summaries, original_model_summaries, instruct_model_summaries))
 
df = pd.DataFrame(zipped_summaries, columns = ['human_baseline_summaries', 'original_model_summaries', 'instruct_model_summaries'])
df

# %% [markdown]
# Evaluate the models computing ROUGE metrics. Notice the improvement in the results!

# %%
original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)

# %% [markdown]
# The file `data/dialogue-summary-training-results.csv` contains a pre-populated list of all model results which you can use to evaluate on a larger section of data. Let's do that for each of the models:

# %%
results = pd.read_csv("data/dialogue-summary-training-results.csv")

human_baseline_summaries = results['human_baseline_summaries'].values
original_model_summaries = results['original_model_summaries'].values
instruct_model_summaries = results['instruct_model_summaries'].values

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)

# %% [markdown]
# The results show substantial improvement in all ROUGE metrics:

# %%
print("Absolute percentage improvement of INSTRUCT MODEL over ORIGINAL MODEL")

improvement = (np.array(list(instruct_model_results.values())) - np.array(list(original_model_results.values())))
for key, value in zip(instruct_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')

# %% [markdown]
# <a name='3'></a>
# ## 3 - Perform Parameter Efficient Fine-Tuning (PEFT)
#
# Now, let's perform **Parameter Efficient Fine-Tuning (PEFT)** fine-tuning as opposed to "full fine-tuning" as you did above. PEFT is a form of instruction fine-tuning that is much more efficient than full fine-tuning - with comparable evaluation results as you will see soon.
#
# PEFT is a generic term that includes **Low-Rank Adaptation (LoRA)** and prompt tuning (which is NOT THE SAME as prompt engineering!). In most cases, when someone says PEFT, they typically mean LoRA. LoRA, at a very high level, allows the user to fine-tune their model using fewer compute resources (in some cases, a single GPU). After fine-tuning for a specific task, use case, or tenant with LoRA, the result is that the original LLM remains unchanged and a newly-trained “LoRA adapter” emerges. This LoRA adapter is much, much smaller than the original LLM - on the order of a single-digit % of the original LLM size (MBs vs GBs).
#
# That said, at inference time, the LoRA adapter needs to be reunited and combined with its original LLM to serve the inference request.  The benefit, however, is that many LoRA adapters can re-use the original LLM which reduces overall memory requirements when serving multiple tasks and use cases.

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Setup the PEFT/LoRA model for Fine-Tuning
#
# You need to set up the PEFT/LoRA model for fine-tuning with a new layer/parameter adapter. Using PEFT/LoRA, you are freezing the underlying LLM and only training the adapter. Have a look at the LoRA configuration below. Note the rank (`r`) hyper-parameter, which defines the rank/dimension of the adapter to be trained.

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    r=32, # Rank
    lora_alpha=32,
    target_modules=["q", "v"],
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM # FLAN-T5
)

# %% [markdown]
# Add LoRA adapter layers/parameters to the original LLM to be trained.

# %%
peft_model = get_peft_model(original_model, 
                            lora_config)
print(print_number_of_trainable_model_parameters(peft_model))

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Train PEFT Adapter
#
# Define training arguments and create `Trainer` instance.

# %%
output_dir = f'./peft-dialogue-summary-training-{str(int(time.time()))}'

peft_training_args = TrainingArguments(
    output_dir=output_dir,
    auto_find_batch_size=True,
    learning_rate=1e-3, # Higher learning rate than full fine-tuning.
    num_train_epochs=1,
    logging_steps=1,
    max_steps=1    
)
    
peft_trainer = Trainer(
    model=peft_model,
    args=peft_training_args,
    train_dataset=tokenized_datasets["train"],
)

# %% [markdown]
# Now everything is ready to train the PEFT adapter and save the model.
#
# <img src="data:image/svg+xml;base64,..." alt="Time alert open medium"/>

# %%
peft_trainer.train()

peft_model_path="./peft-dialogue-summary-checkpoint-local"

peft_trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="Time alert close"/>

# %% [markdown]
# That training was performed on a subset of data. To load a fully trained PEFT model, read a checkpoint of a PEFT model from S3.

# %%
# !aws s3 cp --recursive s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint/ ./peft-dialogue-summary-checkpoint-from-s3/
# Out:
# Completed 334 Bytes/15.9 MiB (518 Bytes/s) with 5 file(s) remaining
# download: s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint/adapter_config.json to peft-dialogue-summary-checkpoint-from-s3\adapter_config.json
# Completed 334 Bytes/15.9 MiB (518 Bytes/s) with 4 file(s) remaining
# Completed 2.5 KiB/15.9 MiB (3.8 KiB/s) with 4 file(s) remaining
# download: s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint/special_tokens_map.json to peft-dialogue-summary-checkpoint-from-s3\special_tokens_map.json
# Completed 2.5 KiB/15.9 MiB (3.8 KiB/s) with 3 file(s) remaining
# Completed 4.9 KiB/15.9 MiB (7.2 KiB/s) with 3 file(s) remaining
# download: s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint/tokenizer_config.json to peft-dialogue-summary-checkpoint-from-s3\tokenizer_config.json
# Completed 4.9 KiB/15.9 MiB (7.2 KiB/s) with 2 file(s) remaining
# Completed 260.9 KiB/15.9 MiB (340.7 KiB/s) with 2 file(s) remaining
# Completed 516.9 KiB/15.9 MiB (669.2 KiB/s) with 2 file(s) remaining
# Completed 772.9 KiB/15.9 MiB (999.4 KiB/s) with 2 file(s) remaining
# Completed 1.0 MiB/15.9 MiB (1.3 MiB/s) with 2 file(s) remaining
# Completed 1.3 MiB/15.9 MiB (1.5 MiB/s) with 2 file(s) remaining
# Completed 1.5 MiB/15.9 MiB (1.8 MiB/s) with 2 file(s) remaining
# Completed 1.8 MiB/15.9 MiB (2.1 MiB/s) with 2 file(s) remaining
# Completed 2.0 MiB/15.9 MiB (2.4 MiB/s) with 2 file(s) remaining
# Completed 2.3 MiB/15.9 MiB (2.6 MiB/s) with 2 file(s) remaining
# Completed 2.5 MiB/15.9 MiB (2.9 MiB/s) with 2 file(s) remaining
# Completed 2.8 MiB/15.9 MiB (3.1 MiB/s) with 2 file(s) remaining
# Completed 3.0 MiB/15.9 MiB (3.4 MiB/s) with 2 file(s) remaining
# Completed 3.3 MiB/15.9 MiB (3.6 MiB/s) with 2 file(s) remaining
# Completed 3.5 MiB/15.9 MiB (3.8 MiB/s) with 2 file(s) remaining
# Completed 3.8 MiB/15.9 MiB (4.0 MiB/s) with 2 file(s) remaining
# Completed 4.0 MiB/15.9 MiB (4.2 MiB/s) with 2 file(s) remaining
# Completed 4.3 MiB/15.9 MiB (4.5 MiB/s) with 2 file(s) remaining
# Completed 4.5 MiB/15.9 MiB (4.7 MiB/s) with 2 file(s) remaining
# Completed 4.8 MiB/15.9 MiB (4.8 MiB/s) with 2 file(s) remaining
# Completed 4.8 MiB/15.9 MiB (4.9 MiB/s) with 2 file(s) remaining
# Completed 5.1 MiB/15.9 MiB (5.1 MiB/s) with 2 file(s) remaining
# download: s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint
MiB (8.8 MiB/s) with 1 file(s) remaining
# Completed 13.6 MiB/15.9 MiB (8.8 MiB/s) with 1 file(s) remaining
# Completed 13.9 MiB/15.9 MiB (8.9 MiB/s) with 1 file(s) remaining
# Completed 14.1 MiB/15.9 MiB (8.9 MiB/s) with 1 file(s) remaining
# Completed 14.4 MiB/15.9 MiB (9.0 MiB/s) with 1 file(s) remaining
# Completed 14.6 MiB/15.9 MiB (9.0 MiB/s) with 1 file(s) remaining
# Completed 14.9 MiB/15.9 MiB (9.0 MiB/s) with 1 file(s) remaining
# Completed 15.1 MiB/15.9 MiB (9.1 MiB/s) with 1 file(s) remaining
# Completed 15.4 MiB/15.9 MiB (9.1 MiB/s) with 1 file(s) remaining
# Completed 15.6 MiB/15.9 MiB (9.2 MiB/s) with 1 file(s) remaining
# Completed 15.9 MiB/15.9 MiB (9.2 MiB/s) with 1 file(s) remaining
# download: s3://dlai-generative-ai/models/peft-dialogue-summary-checkpoint/adapter_model.bin to peft-dialogue-summary-checkpoint-from-s3\adapter_model.bin

# %% [markdown]
# Check that the size of this model is much less than the original LLM:

# %%
# !ls -al ./peft-dialogue-summary-checkpoint-from-s3/adapter_model.bin

# %% [markdown]
# Prepare this model by adding an adapter to the original FLAN-T5 model. You are setting `is_trainable=False` because the plan is only to perform inference with this PEFT model. If you were preparing the model for further training, you would set `is_trainable=True`.

# %%
from peft import PeftModel, PeftConfig

peft_model_base = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base", torch_dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")

peft_model = PeftModel.from_pretrained(peft_model_base, 
                                       './peft-dialogue-summary-checkpoint-from-s3/', 
                                       torch_dtype=torch.bfloat16,
                                       is_trainable=False)

# %% [markdown]
# The number of trainable parameters will be `0` due to `is_trainable=False` setting:

# %%
print(print_number_of_trainable_model_parameters(peft_model))

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - Evaluate the Model Qualitatively (Human Evaluation)
#
# Make inferences for the same example as in sections [1.3](#1.3) and [2.3](#2.3), with the original model, fully fine-tuned and PEFT model.

# %%
index = 200
dialogue = dataset['test'][index]['dialogue']
baseline_human_summary = dataset['test'][index]['summary']

prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """

input_ids = tokenizer(prompt, return_tensors="pt").input_ids

original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

peft_model_outputs = peft_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200, num_beams=1))
peft_model_text_output = tokenizer.decode(peft_model_outputs[0], skip_special_tokens=True)

print(dash_line)
print(f'BASELINE HUMAN SUMMARY:\n{human_baseline_summary}')
print(dash_line)
print(f'ORIGINAL MODEL:\n{original_model_text_output}')
print(dash_line)
print(f'INSTRUCT MODEL:\n{instruct_model_text_output}')
print(dash_line)
print(f'PEFT MODEL: {peft_model_text_output}')

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Evaluate the Model Quantitatively (with ROUGE Metric)
# Perform inferences for the sample of the test dataset (only 10 dialogues and summaries to save time).

# %%
dialogues = dataset['test'][0:10]['dialogue']
human_baseline_summaries = dataset['test'][0:10]['summary']

original_model_summaries = []
instruct_model_summaries = []
peft_model_summaries = []

for idx, dialogue in enumerate(dialogues):
    prompt = f"""
Summarize the following conversation.

{dialogue}

Summary: """
    
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids

    human_baseline_text_output = human_baseline_summaries[idx]
    
    original_model_outputs = original_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    original_model_text_output = tokenizer.decode(original_model_outputs[0], skip_special_tokens=True)

    instruct_model_outputs = instruct_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    instruct_model_text_output = tokenizer.decode(instruct_model_outputs[0], skip_special_tokens=True)

    peft_model_outputs = peft_model.generate(input_ids=input_ids, generation_config=GenerationConfig(max_new_tokens=200))
    peft_model_text_output = tokenizer.decode(peft_model_outputs[0], skip_special_tokens=True)

    original_model_summaries.append(original_model_text_output)
    instruct_model_summaries.append(instruct_model_text_output)
    peft_model_summaries.append(peft_model_text_output)

zipped_summaries = list(zip(human_baseline_summaries, original_model_summaries, instruct_model_summaries, peft_model_summaries))
 
df = pd.DataFrame(zipped_summaries, columns = ['human_baseline_summaries', 'original_model_summaries', 'instruct_model_summaries', 'peft_model_summaries'])
df

# %% [raw]
# Compute ROUGE score for this subset of the data.

# %%
rouge = evaluate.load('rouge')

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

peft_model_results = rouge.compute(
    predictions=peft_model_summaries,
    references=human_baseline_summaries[0:len(peft_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
print('PEFT MODEL:')
print(peft_model_results)

# %% [markdown]
# Notice, that PEFT model results are not too bad, while the training process was much easier!

# %% [markdown]
# You already computed ROUGE score on the full dataset, after loading the results from the `data/dialogue-summary-training-results.csv` file. Load the values for the PEFT model now and check its performance compared to other models.

# %%
human_baseline_summaries = results['human_baseline_summaries'].values
original_model_summaries = results['original_model_summaries'].values
instruct_model_summaries = results['instruct_model_summaries'].values
peft_model_summaries     = results['peft_model_summaries'].values

original_model_results = rouge.compute(
    predictions=original_model_summaries,
    references=human_baseline_summaries[0:len(original_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

instruct_model_results = rouge.compute(
    predictions=instruct_model_summaries,
    references=human_baseline_summaries[0:len(instruct_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

peft_model_results = rouge.compute(
    predictions=peft_model_summaries,
    references=human_baseline_summaries[0:len(peft_model_summaries)],
    use_aggregator=True,
    use_stemmer=True,
)

print('ORIGINAL MODEL:')
print(original_model_results)
print('INSTRUCT MODEL:')
print(instruct_model_results)
print('PEFT MODEL:')
print(peft_model_results)

# %% [markdown]
# The results show less of an improvement over full fine-tuning, but the benefits of PEFT typically outweigh the slightly-lower performance metrics.
#
# Calculate the improvement of PEFT over the original model:

# %%
print("Absolute percentage improvement of PEFT MODEL over ORIGINAL MODEL")

improvement = (np.array(list(peft_model_results.values())) - np.array(list(original_model_results.values())))
for key, value in zip(peft_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')

# %% [markdown]
# Now calculate the improvement of PEFT over a full fine-tuned model:

# %%
print("Absolute percentage improvement of PEFT MODEL over INSTRUCT MODEL")

improvement = (np.array(list(peft_model_results.values())) - np.array(list(instruct_model_results.values())))
for key, value in zip(peft_model_results.keys(), improvement):
    print(f'{key}: {value*100:.2f}%')

# %% [markdown]
# Here you see a small percentage decrease in the ROUGE metrics vs. full fine-tuned. However, the training requires much less computing and memory resources (often just a single GPU).
