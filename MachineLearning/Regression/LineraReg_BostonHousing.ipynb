# %% [markdown]
# This dataset i use linear regression as the data is continous and house price will be predicted based on square feet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'boston-housing\train.csv')

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
df.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
# Remove the last column and store it in x
x = df.iloc[:, :-1]

# Store the last column in y
y = df.iloc[:, -1]

# %%
# Plot histograms for each column in x
for column in x.columns:
    plt.figure()
    plt.hist(x[column], bins=25)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
plt.hist(y, bins=25)
# Out:
# (array([ 2.,  8.,  5., 13., 19., 19., 20., 32., 41., 40., 46., 12., 12.,
#          7., 10., 10.,  7.,  7.,  2.,  1.,  2.,  2.,  2.,  0., 14.]),
#  array([ 5. ,  6.8,  8.6, 10.4, 12.2, 14. , 15.8, 17.6, 19.4, 21.2, 23. ,
#         24.8, 26.6, 28.4, 30.2, 32. , 33.8, 35.6, 37.4, 39.2, 41. , 42.8,
#         44.6, 46.4, 48.2, 50. ]),
#  <BarContainer object of 25 artists>)

# %%
correlation_matrix = df.corr()
# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# i dont see any strong correlation of Medv with other variables. hence looking at Kde to check distribution and box plot for checking outloers

# %%
for column in df.columns:
    sns.kdeplot(data=df,x=column)
    plt.show()
# Out:
# c:\Users\paish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\paish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\paish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig,ax=plt.subplots(ncols=13,nrows=1,figsize=(25,10),dpi=400)
i=0

for column in df.columns:

    sns.boxplot(data=df,y=column,ax=ax[i])
    i=i+1
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 6
#       2 i=0
#       4 for column in df.columns:
# ----> 6     sns.boxplot(data=df,y=column,ax=ax[i])
#       7     i=i+1
#       9 plt.tight_layout()
#
# IndexError: index 13 is out of bounds for axis 0 with size 13

# %% [markdown]
# many fields have outliers

# %%
#finding correlation
corr_matrix_medv = df.corr()["medv"]
corr_matrix_medv
# Out:
# ID        -0.221694
# crim      -0.407454
# zn         0.344842
# indus     -0.473932
# chas       0.204390
# nox       -0.413054
# rm         0.689598
# age       -0.358888
# dis        0.249422
# rad       -0.352251
# tax       -0.448078
# ptratio   -0.481376
# black      0.336660
# lstat     -0.738600
# medv       1.000000
# Name: medv, dtype: float64

# %% [markdown]
# all data is in form of neumeric and floating ponints, so its easy to train model and test using MSE

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2,random_state = 0)

  
print("xtrain shape : ", x_train.shape)
print("xtest shape  : ", x_test.shape)
print("ytrain shape : ", y_train.shape)
print("ytest shape  : ", y_test.shape)
# Out:
# xtrain shape :  (266, 14)
# xtest shape  :  (67, 14)
# ytrain shape :  (266,)
# ytest shape  :  (67,)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train,y_train)

y_pred = regressor.predict(x_test)

# %%
plt.scatter(y_test, y_pred, c = 'green')

# %%
plt.scatter(y_test, y_pred, c = 'green')
# Plot a line of best fit
x = [min(y_test), max(y_test)]
y = [min(y_test), max(y_test)]
plt.plot(x, y, 'r')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test,y_pred)
print("Mean Square Error : ", mse)
print("Mean Absolute Error : ", mae)
# Out:
# Mean Square Error :  23.821583889010906
# Mean Absolute Error :  3.2893229405345457

# %%
# Calculate RMSE
rmse = np.sqrt(mse)
print("Root Mean square error : ", rmse)
# Out:
# Root Mean square error :  4.8807359987004935
